# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the CSV file into a DataFrame named "df5"
df5 = pd.read_csv("df5.csv")

# Show the column names of the DataFrame
df5.columns.tolist()
# Out:
# ['approach_Collaborate_with_Artists',
#  'approach_Collaborate_with_Non_Arts',
#  'approach_Community_Involvement',
#  'approach_Core_Presenting',
#  'approach_Core_Teaching',
#  'approach_Solo_Artist',
#  'assistance_Emergency_Grant',
#  'assistance_Family_Personal_Assist',
#  'assistance_Federal_Relief',
#  'assistance_Mutual_Aid',
#  'assistance_Other_Assistance',
#  'assistance_Unemployment_Benefits',
#  'care_Adult_Caregiving',
#  'care_Child_Caregiving',
#  'care_No_Caregiving',
#  'care_Provide_Care_No_Answer',
#  'care_Spouse_or_Partner_Caregiving',
#  'city',
#  'community',
#  'county',
#  'discip_Craft',
#  'discip_Dance',
#  'discip_Design',
#  'discip_Film',
#  'discip_Interdisciplinary_Arts',
#  'discip_Literary_Arts',
#  'discip_Media_Arts',
#  'discip_Music',
#  'discip_Oral_Traditions',
#  'discip_Performance_Art',
#  'discip_Social_Practice',
#  'discip_Theater',
#  'discip_Traditional_Arts',
#  'discip_Visual_Arts',
#  'earn_100_art_practice',
# ...

# %%
# Provided mapping context as a string. Each line represents a mapping from "Questions" to "Column Names"

# Read the Excel file into a DataFrame
dictionary_ques = pd.read_excel('Book1.xlsx')

dictionary_ques.head()
# Out:
#            questions                        column_names
# 0  artistic_approach   approach_Collaborate_with_Artists
# 1                NaN  approach_Collaborate_with_Non_Arts
# 2                NaN      approach_Community_Involvement
# 3                NaN            approach_Core_Presenting
# 4                NaN              approach_Core_Teaching

# %%
# Convert the DataFrame to a dictionary
# Initialize an empty dictionary
data_dict = {}

# Initialize current_key to None
current_key = None

# Loop through each row in the DataFrame
for index, row in dictionary_ques.iterrows():
    question = row['questions']
    column_name = row['column_names']
    
    # Check if 'question' is NaN. If not, update current_key
    if pd.notna(question):
        current_key = question
        data_dict[current_key] = []
        
    # Append 'column_name' to the list corresponding to 'current_key'
    if pd.notna(column_name):
        data_dict[current_key].append(column_name)

print(data_dict)
# Out:
# {'artistic_approach': ['approach_Collaborate_with_Artists', 'approach_Collaborate_with_Non_Arts', 'approach_Community_Involvement', 'approach_Core_Presenting', 'approach_Core_Teaching', 'approach_Solo_Artist'], 'assistance': ['assistance_Emergency_Grant', 'assistance_Family_Personal_Assist', 'assistance_Federal_Relief', 'assistance_Mutual_Aid', 'assistance_Other_Assistance', 'assistance_Unemployment_Benefits'], 'financialy_dependent': ['care_Adult_Caregiving', 'care_Child_Caregiving', 'care_No_Caregiving', 'care_Provide_Care_No_Answer', 'care_Spouse_or_Partner_Caregiving'], 'city': ['city'], 'community': ['community'], 'county': ['county'], 'art_discipline': ['discip_Craft', 'discip_Dance', 'discip_Design', 'discip_Film', 'discip_Interdisciplinary_Arts', 'discip_Literary_Arts', 'discip_Media_Arts', 'discip_Music', 'discip_Oral_Traditions', 'discip_Performance_Art', 'discip_Social_Practice', 'discip_Theater', 'discip_Traditional_Arts', 'discip_Visual_Arts'], 'earning_info': ['earn_100
# ...

# %%
# Saving the dictionary to a JSON file for future reference
# import json

# Create a dictionary to hold the column names mapping
# column_name_mapping_dict = {}

# Iterate through the DataFrame to populate the dictionary
# for index, row in df.iterrows():
#     key = row['questions']
#     value = row['column_names']
#     if key in column_name_mapping_dict:
#         column_name_mapping_dict[key].append(value)
#     else:
#         column_name_mapping_dict[key] = [value]

# # Save the dictionary as a JSON file
# column_name_mapping_json_path = 'C:/Users/95san/Desktop/Academics/contests/CRNY Visualization Contest/Data Set/column_name_mapping.json'
# with open(column_name_mapping_json_path, 'w') as f:
#     json.dump(column_name_mapping_dict, f)

# column_name_mapping_dict, column_name_mapping_json_path

# %%
# Start with the first key for internal visualizations
key_main = "artistic_approach"  # Use "approach" as the key name
key_columns = data_dict[key_main]

# # import matplotlib.pyplot as plt
# # import seaborn as sns

# # Calculate the count of 1s in each column
# count_of_ones = df5[key_columns].sum()

# # Create the bar plot
# plt.figure(figsize=(10, 4))
# sns.barplot(x=key_columns, y=count_of_ones)
# plt.title(f'Count of 1s in Each Column for {key_main}')
# plt.xlabel('Columns')
# plt.ylabel('Count of 1s')
# plt.xticks(rotation=9, ha="right")
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

key_main = "artistic_approach"
key_columns = data_dict[key_main]

# Calculate the count of 1s in each column
count_of_ones = df5[key_columns].sum()
# print(list(count_of_ones.keys()))

# Sort the columns by descending order of the count of 1s
sorted_columns = count_of_ones.sort_values(ascending=False).index

# Calculate the total count
total_count = sum(count_of_ones)
print(total_count)

dict_ = count_of_ones.to_dict()

# Calculate the percentage distribution for each key
percentage_distribution = {key: (value / total_count) * 100 for key, value in dict_.items()}
print(percentage_distribution)

# Remove "approach_" from the x-axis parameter labels
cleaned_labels = [label.replace("approach_", "") for label in sorted_columns]

# Create a horizontal bar plot with fading colors
plt.figure(figsize=(13, 6))
palette = sns.color_palette("Blues_r", len(cleaned_labels))  # Fading colors from high to low
ax = sns.barplot(x=count_of_ones[sorted_columns], y=cleaned_labels, orient="h", palette=palette)

# Annotate the count of each category inside the bar
for i, v in enumerate(count_of_ones[sorted_columns]):
    ax.text(v + 5, i, str(v), va='center', fontsize=12)  # Adjust the position for better readability

plt.title('Artistic Approach')  # Updated title
plt.xlabel('Number of Artists →')
plt.ylabel('Approach →')
plt.show()
# Out:
# 72988
# {'approach_Collaborate_with_Artists': 20.659560475694636, 'approach_Collaborate_with_Non_Arts': 9.152189400997424, 'approach_Community_Involvement': 13.080232366964434, 'approach_Core_Presenting': 18.751027566175264, 'approach_Core_Teaching': 12.806214720227981, 'approach_Solo_Artist': 25.550775469940262}

# %%
import plotly.express as px
import pandas as pd

# Assuming 'count_of_ones' and 'cleaned_labels' are available from previous calculations

# import seaborn as sns
# import matplotlib.pyplot as plt

key_main = "artistic_approach"
key_columns = data_dict[key_main]

# Calculate the count of 1s in each column
count_of_ones = df5[key_columns].sum()

# Sort the columns by descending order of the count of 1s
sorted_columns = count_of_ones.sort_values(ascending=False).index

# Remove "approach_" from the x-axis parameter labels
cleaned_labels = [label.replace("approach_", "") for label in sorted_columns]
# Create a DataFrame for plotting
plot_data = pd.DataFrame({
    'Count': count_of_ones[sorted_columns],
    'Approach': cleaned_labels
})

# Create a horizontal bar plot with fading colors
fig = px.bar(plot_data, x='Count', y='Approach', orientation='h',
             color='Count', color_continuous_scale='fall', 
             title='Artistic Approach', labels={'Count': 'Number of Artists →', 'Approach': 'Approach →'})

# Add text annotations
for i, v in enumerate(count_of_ones[sorted_columns]):
    fig.add_annotation(x=v + 5, y=cleaned_labels[i], text=str(v),
                       showarrow=False, align="right", font=dict(size=12))

fig.show()
# Out:
# <div>                            <div id="22d4eb3f-e742-4b1d-bd6e-6af69c836978" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22d4eb3f-e742-4b1d-bd6e-6af69c836978")) {                    Plotly.newPlot(                        "22d4eb3f-e742-4b1d-bd6e-6af69c836978",                        [{"alignmentgroup":"True","hovertemplate":"Number of Artists \u2192=%{marker.color}<br>Approach \u2192=%{y}<extra></extra>","legendgroup":"","marker":{"color":[18649,15079,13686,9547,9347,6680],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[18649,15079,13686,9547,9347,6680],"xaxis":"x","y":["Solo_Artist","Collaborate_with_Artists","Core_Presenting","Community_Involvement","
# ...

# %%
# import plotly.express as px
# import pandas as pd

# # Assuming 'count_of_ones', 'cleaned_labels', and 'df5' are available from previous calculations
# # Assuming 'Additional_Info' is an additional column in your dataset

# key_main = "artistic_approach"
# key_columns = data_dict[key_main]

# # Calculate the count of 1s in each column
# count_of_ones = df5[key_columns].sum()
# print(count_of_ones)

# # Sort the columns by descending order of the count of 1s
# sorted_columns = count_of_ones.sort_values(ascending=False).index

# total_count = sum(count_of_ones)
# print(total_count)

# dict_ = count_of_ones.to_dict()

# # Calculate the percentage distribution for each key
# percentage_distribution = {key: (value / total_count) * 100 for key, value in dict_.items()}
# print(percentage_distribution)


# # Remove "approach_" from the x-axis parameter labels
# cleaned_labels = [label.replace("approach_", "") for label in sorted_columns]
# print(cleaned_labels)

# # Assuming 'Additional_Info' is an additional column in your dataset
# sorted(list(percentage_distribution.values()),reverse=True)  # Replace 'Additional_Info' with your actual column name

# # Create a DataFrame for plotting
# plot_data = pd.DataFrame({
#     'Count': count_of_ones[sorted_columns],
#     'Approach': cleaned_labels,
#     'Additional_Info': additional_info  # Add the additional information to display on hover
# })

# # Create a horizontal bar plot with fading colors
# fig = px.bar(plot_data, x='Count', y='Approach', orientation='h',
#              color='Count', color_continuous_scale='Blues', 
#              title='Artistic Approach', labels={'Count': 'Number of Artists →', 'Approach': 'Approach →'},
#              hover_name='Approach', hover_data={'Count': True, 'Approach': False, 'Additional_Info': True})

# # Add text annotations
# for i, v in enumerate(count_of_ones[sorted_columns]):
#     fig.add_annotation(x=v + 5, y=cleaned_labels[i], text=str(v),
#                        showarrow=False, font=dict(size=12))

# fig.show()

# %%
sorted(list(percentage_distribution.values()),reverse=True)
# Out:
# [25.550775469940262,
#  20.659560475694636,
#  18.751027566175264,
#  13.080232366964434,
#  12.806214720227981,
#  9.152189400997424]

# %%
sorted(list(percentage_distribution.values()),reverse=True)
# Out:
# [25.550775469940262,
#  20.659560475694636,
#  18.751027566175264,
#  13.080232366964434,
#  12.806214720227981,
#  9.152189400997424]

# %%
key_main = "practice_impact" 
key_columns = data_dict[key_main]

# Calculate the count of 1s in each column
count_of_ones = df5[key_columns].sum()

# Sort the columns by ascending order of the count of 1s
sorted_columns = count_of_ones.sort_values(ascending=False).index

# Create the bar plot with sorted columns
plt.figure(figsize=(10, 4))
sns.barplot(x=sorted_columns, y=count_of_ones[sorted_columns])
plt.title(f'Count of 1s in Each Column for {key_main}')
plt.xlabel('Columns')
plt.ylabel('Count of 1s')
plt.xticks(rotation=50, ha="right")
plt.show()

# %%
import plotly.express as px

key_main = "race"
key_columns = data_dict[key_main]

# Calculate the count of 1s in each column
count_of_ones = df5[key_columns].sum()

# Sort the columns by ascending order of the count of 1s
sorted_columns = count_of_ones.sort_values(ascending=False).index

# Create a DataFrame for the plot
df_plot = pd.DataFrame({'Columns': sorted_columns, 'Count of 1s': count_of_ones[sorted_columns]})

# Calculate the percentage
df_plot['Percentage'] = (df_plot['Count of 1s'] / df_plot['Count of 1s'].sum()) * 100

# Create a donut chart using Plotly
fig = px.pie(df_plot, names='Columns', values='Percentage', hole=0.4, title=f'Artists distribution as per {key_main}')

# Show the chart
fig.show()
# Out:
# <div>                            <div id="f3e12235-256c-4189-9573-47a88a612ead" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3e12235-256c-4189-9573-47a88a612ead")) {                    Plotly.newPlot(                        "f3e12235-256c-4189-9573-47a88a612ead",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Columns=%{label}<br>Percentage=%{value}<extra></extra>","labels":["Race_Ethnicity_White","Race_Ethnicity_Black_African_American","Race_Ethnicity_Hispanic_Latinx","Race_Ethnicity_Asian","Race_Ethnicity_Other","Race_Ethnicity_Indigenous_American_First_Nation","Race_Ethnicity_No_Answer","Race_Ethnicity_Arab_or_Middle_Eastern","Race_Ethnicity_Prefer_Not_to_Say_Race"],"legendgroup":"","name":"","showl
# ...

# %%
# print(data_dict)

# %%
# import seaborn as sns
# sns.pairplot(df5[['p_age', 'p12_healthinsurance', 'p16_mentalhealth', 'p20_purposefullife']])

# %%
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt

# text_data = df5['p31_artpracticeimpact_othdesc'].dropna().str.cat(sep=' ')
# wordcloud = WordCloud(width=800, height=400).generate(text_data)

# plt.figure(figsize=(10, 5))
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# plt.show()

# %%
# import plotly.express as px

# # Remove rows with missing or invalid 'p_age' values
# df5_cleaned = df5.dropna(subset=['p_age'])

# fig = px.scatter_geo(df5_cleaned, locations="zipcode", locationmode="USA-states", 
#                       hover_name="city",
#                      title="Geospatial Distribution of Impacts")
# fig.update_geos(fitbounds="locations", visible=False)
# fig.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Select only the numeric columns from your DataFrame
# numeric_columns = df5.select_dtypes(include=['number'])

# corr_matrix = numeric_columns.corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
# plt.title('Correlation Heatmap')
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Create a pie chart
plt.figure(figsize=(8, 6))
labels = df5['immigrant.2'].value_counts().index
sizes = df5['immigrant.2'].value_counts().values
colors = ['#808080', '#990000', '#D3D3D3']  # Crimson colors
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors)
plt.title('Imigrated Artists')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df5, x="immigrant.2")
plt.title("Distribution of Immigration Status")
plt.xlabel("Immigration Status")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Set style to 'white' which removes the grid
sns.set(style="white")

# Create the histogram
plt.figure(figsize=(12, 8))
n, bins, patches = plt.hist(df5['p_age'], bins=20, edgecolor='black')

# Normalize the bin heights to get the frequency for color intensity
bin_max = max(n)
crimson_rgb = (220/255, 20/255, 60/255)  # RGB for crimson
colors = [(*crimson_rgb, n_i/bin_max) for n_i in n]  # Fade effect with alpha value

# Apply color gradient to each bar in the histogram
for patch, color in zip(patches, colors):
    patch.set_facecolor(color)

# Add titles and labels
plt.title("Age Distribution of Artists", fontsize=18, fontweight='bold', color='darkslateblue')
plt.xlabel("Age →", fontsize=14, fontweight='bold', color='darkslateblue')
plt.ylabel("Count of Artists → ", fontsize=14, fontweight='bold', color='darkslateblue')

# Calculate and display the average age on the right-hand side of the graph
average_age = df5['p_age'].mean()
plt.text(0.95, 0.95, f"Average Age: {average_age:.1f}", transform=plt.gca().transAxes, horizontalalignment='right',
         verticalalignment='top', fontsize=14, color='darkred', fontweight='bold')

# Customize ticks
plt.xticks(fontsize=12, color='slategray')
plt.yticks(fontsize=12, color='slategray')

# Remove top and right spines for a cleaner look
sns.despine()

plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df5, x="p_status")
plt.title("Distribution Application Status")
plt.xlabel("Admission Status")
plt.ylabel("Count of Artists →")
plt.show()

# %% [markdown]
# # What artistic disciplines are most common among respondents?

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Assuming 'df5' is your dataframe and 'data_dict' contains the mapping for the 'art_discipline' column
key_main = "art_discipline"  # Replace with actual column name for artistic disciplines
key_columns = data_dict[key_main]  # Replace with actual column mappings

# Calculate the count of 1s in each column
count_of_ones = df5[key_columns].sum()

# Sort the counts in descending order to find the most common disciplines
sorted_counts = count_of_ones.sort_values(ascending=False)

# Remove 'discip_' from the column labels
sorted_counts.index = sorted_counts.index.str.replace('discip_', '')

# Calculate the percentage for each discipline
total_responses = len(df5)
percentage = (sorted_counts / total_responses) * 100

# Create a color gradient in the crimson color range with fade effect
n = len(sorted_counts)
crimson_color = (0.6, 0, 0)  # RGB for crimson color
colors = [(*crimson_color, i/n) for i in range(n, 0, -1)]  # Fade effect with alpha value

# Create a bar plot to visualize the counts and percentages
plt.figure(figsize=(14, 8))
ax = plt.bar(sorted_counts.index, sorted_counts.values, color=colors)

# Customize the plot for a more classy and artistic look
plt.title("Most Common Artistic Disciplines", fontsize=18, fontweight='bold', color='darkslategray')
plt.xlabel("Artistic Discipline", fontsize=14, fontweight='bold', color='darkslategray')
plt.ylabel("Count of Artists →", fontsize=14, fontweight='bold', color='darkslategray')
plt.xticks(rotation=0, ha="center", fontsize=7, color='black')
plt.yticks(color='slategray')

# Remove grid and set background color
plt.grid(False)
plt.gca().set_facecolor('whitesmoke')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_color('slategray')
plt.gca().spines['bottom'].set_color('slategray')

# Display the percentages on top of the bars
for rect, perc in zip(ax, percentage):
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height + 5, f"{perc:.2f}%", ha="center", va="bottom", color='darkslategray')

plt.tight_layout()
plt.show()

# %% [markdown]
# # How did the pandemic impact employment?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

key_main = "practice_impact"
key_columns = data_dict[key_main]

# Calculate the count of 1s in each column
count_of_ones = df5[key_columns].sum()

# Sort the columns by descending order of the count of 1s
sorted_columns = count_of_ones.sort_values(ascending=False).index

# Calculate the total count for percentage calculation
total_count = count_of_ones.sum()

# Calculate the percentage for each category
percentage_values = [(count / total_count) * 100 for count in count_of_ones[sorted_columns]]

# Remove "impact_" from the x-axis parameter labels
cleaned_labels = [label.replace("practice_impact_", "") for label in sorted_columns]

# Create a horizontal bar plot with fading colors
plt.figure(figsize=(14, 6))
palette = sns.color_palette("Blues_r", len(cleaned_labels))  # Fading colors from high to low
ax = sns.barplot(x=count_of_ones[sorted_columns], y=cleaned_labels, orient="h", palette=palette)

# Annotate the count and percentage of each category inside the bar
for i, (count,) in enumerate(zip(count_of_ones[sorted_columns])):
    text = f"{count}"
    ax.text(count + 5, i, text, va='center', fontsize=8)  # Adjust the position for better readability

plt.title('Pandemic impact on Artists employment')  # Updated title
plt.xlabel('Count of Artists →')
plt.ylabel('Impacts  →')
plt.xticks( ha="right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

key_main = "practice_impact"
key_columns = data_dict[key_main]

# Calculate the count of 1s in each column
count_of_ones = df5[key_columns].sum()

# Sort the columns by descending order of the count of 1s
sorted_columns = count_of_ones.sort_values(ascending=False).index

# Calculate the total count for percentage calculation
total_count = count_of_ones.sum()

# Calculate the percentage for each category
percentage_values = [(count / total_count) * 100 for count in count_of_ones[sorted_columns]]

# Remove "impact_" from the labels
cleaned_labels = [label.replace("practice_impact_", "") for label in sorted_columns]

# Define colors for the radial bars
colors = plt.cm.Blues(np.linspace(0, 1, len(cleaned_labels)))

# Create a figure and axis with polar projection
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Compute the width of each bar
width = np.pi / len(cleaned_labels)

# Plot each bar
bars = ax.bar(np.linspace(0, 2 * np.pi, len(cleaned_labels), endpoint=False), percentage_values, width=width, bottom=0.0, color=colors)

# Set the labels for each bar
ax.set_xticks(np.linspace(0, 2 * np.pi, len(cleaned_labels), endpoint=False))
ax.set_xticklabels(cleaned_labels, fontsize=8)

plt.title('Pandemic impact on Artists employment')  # Updated title

plt.show()

# %% [markdown]
# What are the top barriers artists face in professional development?
# Create a word cloud showing the most frequently used words and phrases from the open response question.

# %%
# Let's take a look at the contents of 'p4_barriers_othdesc' to understand the data
# We will check the unique values and get a sense of the text data

# Displaying the unique non-empty, non-null text entries in the 'p4_barriers_othdesc' column
barriers_text_responses = df5['p4_barriers_othdesc'].dropna().unique()
barriers_text_responses[:10]  # Show the first 10 responses to get a sense of the data
# Manual tokenization and processing without relying on NLTK resources



from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import configparser
configparser.RawConfigParser

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Function to preprocess the text data
def preprocess_text(text_responses):
    # Concatenate all text responses into a single string
    text = " ".join(text_responses).lower()
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Remove punctuation and numbers
    words = [word for word in tokens if word.isalpha()]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    meaningful_words = [word for word in words if word not in stop_words]
    
    return " ".join(meaningful_words)

# Preprocess the text responses
processed_text = preprocess_text(barriers_text_responses)

# Create and display a word cloud
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(processed_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove axis
plt.title('Word Cloud for Artist Barriers in Professional Development')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [200], in <cell line: 44>()
#      41 processed_text = preprocess_text(barriers_text_responses)
#      43 # Create and display a word cloud
# ---> 44 wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(processed_text)
#      46 # Display the word cloud using matplotlib
#      47 plt.figure(figsize=(15, 7))
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
# ...

# %%
# Define a basic set of English stopwords
basic_stopwords = set([
    "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves",
    "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their",
    "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was",
    "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and",
    "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between",
    "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off",
    "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any",
    "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so",
    "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"
])

# Function to manually preprocess the text data
def manual_preprocess_text(text_responses):
    # Concatenate all text responses into a single string
    text = " ".join(text_responses).lower()
    
    # Replace non-alphabetic characters with spaces
    text = ''.join([char if char.isalpha() else ' ' for char in text])
    
    # Split the text into words
    words = text.split()
    
    # Remove stopwords
    meaningful_words = [word for word in words if word not in basic_stopwords]
    
    return " ".join(meaningful_words)

# Preprocess the text responses using the manual method
manual_processed_text = manual_preprocess_text(barriers_text_responses)

# Create and display a word cloud
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(manual_processed_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove axis
plt.title('Word Cloud for Artist Barriers in Professional Development')
plt.show()

# %% [markdown]
# How does financial stability correlate with well-being factors?
# Create a matrix of scatter plots showing the correlation between financial stability and each well-being statement rating.

# %% [markdown]
# ## How did primary spoken language correlate with awareness of guaranteed income policies?
# Create a stacked bar chart showing awareness by primary language.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the language and awareness columns
language_column = 'language'
awareness_column = 'p26_awareofgi'

# Create a new DataFrame with relevant columns
df_language_awareness = df5[[language_column, awareness_column]]

# Group the data by primary spoken language and awareness responses
language_awareness_counts = df_language_awareness.groupby([language_column, awareness_column]).size().unstack(fill_value=0)

# Normalize the counts to get percentages within each language group
language_awareness_percentage = language_awareness_counts.divide(language_awareness_counts.sum(axis=1), axis=0) * 100

# Reorder the columns to make the plot more interpretable
awareness_order = ["Yes", "No", "Not sure"]
language_awareness_percentage = language_awareness_percentage[awareness_order]

# Create the stacked bar chart
plt.figure(figsize=(12, 6))
language_awareness_percentage.plot(kind='bar', stacked=True, colormap='viridis')

plt.xlabel('Primary Spoken Language')
plt.ylabel('Percentage (%)')
plt.title('Awareness of Guaranteed Income Policies by Primary Spoken Language')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Replacing "," s with Null values
df5['community'].unique()
x=[',']
y=[np.NaN]
df5.replace(x,y,inplace=True)
df5['community'].unique()

# Define the language and awareness columns
language_column = 'community'
awareness_column = 'p26_awareofgi'

# Create a new DataFrame with relevant columns
df_language_awareness = df5[[language_column, awareness_column]]

# Group the data by primary spoken language and awareness responses
language_awareness_counts = df_language_awareness.groupby([language_column, awareness_column]).size().unstack(fill_value=0)

# Normalize the counts to get percentages within each language group
language_awareness_percentage = language_awareness_counts.divide(language_awareness_counts.sum(axis=1), axis=0) * 100

# Reorder the columns to make the plot more interpretable
awareness_order = ["Yes", "No", "Not sure"]
language_awareness_percentage = language_awareness_percentage[awareness_order]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Replacing "," s with Null values
df5['community'].unique()
x = [',']
y = [np.NaN]
df5.replace(x, y, inplace=True)
df5['community'].unique()

# Define the desired order of communities
community_order = ["Tribal", "Suburban", "Urban", "Rural"]

# Apply the custom order to the 'community' column
df5['community'] = pd.Categorical(df5['community'], categories=community_order, ordered=True)

# Define the language and awareness columns
language_column = 'community'
awareness_column = 'p26_awareofgi'

# Create a new DataFrame with relevant columns
df_language_awareness = df5[[language_column, awareness_column]]

# Group the data by primary spoken language and awareness responses
language_awareness_counts = df_language_awareness.groupby([language_column, awareness_column]).size().unstack(fill_value=0)

# Normalize the counts to get percentages within each language group
language_awareness_percentage = language_awareness_counts.divide(language_awareness_counts.sum(axis=1), axis=0) * 100

# Reorder the columns to make the plot more interpretable
awareness_order = ["Yes", "No", "Not sure"]
language_awareness_percentage = language_awareness_percentage[awareness_order]

# Create the stacked bar chart with the custom order
plt.figure(figsize=(12, 6))
language_awareness_percentage.plot(kind='bar', stacked=True, colormap='Set2')

plt.xlabel('Community Type')
plt.ylabel('Percentage (%)')
plt.title('Awareness of Guaranteed Income Policies by Community Type')

plt.legend(title='Awareness', loc='upper left', labels=['Yes', 'No', 'Not sure'])

plt.tight_layout()
plt.show()

# %%
import numpy as np
df5['community'].unique()
x=[',']
y=[np.NaN]
df5.replace(x,y,inplace=True)
df5['community'].unique()
# Out:
# ['Urban', 'Rural', 'Suburban', NaN, 'Tribal']
# Categories (4, object): ['Tribal' < 'Suburban' < 'Urban' < 'Rural']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the language and awareness columns
language_column = 'p8_financialstability'
awareness_column = 'p26_awareofgi'

# Create a new DataFrame with relevant columns
df_language_awareness = df5[[language_column, awareness_column]]

# Group the data by primary spoken language and awareness responses
language_awareness_counts = df_language_awareness.groupby([language_column, awareness_column]).size().unstack(fill_value=0)

# Normalize the counts to get percentages within each language group
language_awareness_percentage = language_awareness_counts.divide(language_awareness_counts.sum(axis=1), axis=0) * 100

# Reorder the columns to make the plot more interpretable
awareness_order = ["Yes", "No", "Not sure"]
language_awareness_percentage = language_awareness_percentage[awareness_order]

# Create the stacked bar chart
plt.figure(figsize=(12, 6))
language_awareness_percentage.plot(kind='bar', stacked=True, colormap='viridis')

plt.xlabel('Primary Spoken Language')
plt.ylabel('Percentage (%)')
plt.title('Awareness of Guaranteed Income Policies by financial stability')

plt.tight_layout()
plt.show()

# %%
assistance_columns = [col for col in df5.columns if 'assistance_' in col]
# assistance_data = df5[assistance_columns].sum().sort_values()
assistance_columns=assistance_columns[:len(assistance_columns)-1]
assistance_columns
# Out:
# ['assistance_Emergency_Grant',
#  'assistance_Family_Personal_Assist',
#  'assistance_Federal_Relief',
#  'assistance_Mutual_Aid',
#  'assistance_Other_Assistance',
#  'assistance_Unemployment_Benefits']

# %%
assistance_data = df5[assistance_columns].sum().sort_values()
assistance_data.values
# Out:
# array([ 484,  595, 1420, 1860, 3318, 7359], dtype=int64)

# %%
# Set up the visualisation settings
sns.set(style="whitegrid")

# Calculate the sum of each 'approach' column to see how many artists engage in each approach
approach_columns = [col for col in df5.columns if 'approach_' in col]
approach_data = df5[approach_columns].sum().sort_values()

# Plot for approach data
sns.barplot(x=approach_data.values, y=approach_data.index, ax=ax[0], palette="viridis")

# Create a bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x=approach_data.values, y=approach_data.index, palette='viridis')
ax[0].set_title('Prevalence of Artistic Approaches')
ax[0].set_xlabel('Number of Artists')
ax[0].set_ylabel('Approaches')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [208], in <cell line: 9>()
#       6 approach_data = df5[approach_columns].sum().sort_values()
#       8 # Plot for approach data
# ----> 9 sns.barplot(x=approach_data.values, y=approach_data.index, ax=ax[0], palette="viridis")
#      11 # Create a bar chart
#      12 plt.figure(figsize=(12, 8))
#
# TypeError: 'PolarAxesSubplot' object is not subscriptable

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set up the visualisation settings
sns.set(style="whitegrid")

assistance_columns = [col for col in df5.columns if 'assistance_' in col]
assistance_columns=assistance_columns[:len(assistance_columns)-1]
# assistance_columns
assistance_data = df5[assistance_columns].sum().sort_values()

# Create a bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x=assistance_data.values, y=assistance_data.index, palette='magma')

# Add titles and labels
plt.title('Types of Assistance Received by Artists')
plt.xlabel('Number of Artists')
plt.ylabel('Types of Assistance')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import plotly.express as px
import streamlit as st

def create_plot_4(data_dict, df5):
    earning_info_columns = data_dict['earning_info']  # Assuming 'data_dict' is your dictionary
    earning_info_sums = df5[earning_info_columns].sum()
    sorted_sums = earning_info_sums.sort_values(ascending=False)
    
    # Create a dataframe from the sorted data
    data = pd.DataFrame({'Attributes': sorted_sums.index, 'Count of Positive Responses (1s)': sorted_sums.values})
    
    # Remove 'earn_' prefix from y-axis labels
    data['Attributes'] = data['Attributes'].str.replace('earn_', '')
    
    # Create the bar chart using Plotly Express
    fig = px.bar(data, x='Count of Positive Responses (1s)', y='Attributes', orientation='h')

    # Update layout for better visualization (optional)
    fig.update_layout(title='Counts of Positive Responses for Earning Information Attributes',
                      height=600, width=800)  # Adjust size as needed

    return fig

fig = create_plot_4(data_dict, df5)
fig.show()

# # Display the Plotly figure in Streamlit
# st.plotly_chart(fig)
# Out:
# <div>                            <div id="dd611976-b9c9-448b-98cf-b40846c7a898" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd611976-b9c9-448b-98cf-b40846c7a898")) {                    Plotly.newPlot(                        "dd611976-b9c9-448b-98cf-b40846c7a898",                        [{"alignmentgroup":"True","hovertemplate":"Count of Positive Responses (1s)=%{x}<br>Attributes=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[6008,4419,3630,2366,1447,1189],"xaxis":"x","y":["Gigs_Contracts","Part_Time_Job","Unemployed","100_art_practice","Supported_by_Family","Full_Time_Job"],"yaxis":"y","type":"bar"}],            
# ...

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import squarify  # Import the squarify package

# Your data preparation (similar to the code you provided)
sns.set(style="whitegrid")

assistance_columns = [col for col in df5.columns if 'assistance_' in col]
assistance_columns = assistance_columns[:len(assistance_columns) - 1]
assistance_data = df5[assistance_columns].sum().sort_values()

# Create a dataframe from the sorted data
data = pd.DataFrame({'count': assistance_data.values}, index=assistance_data.index)

# Calculate the sizes for squarify
sizes = data['count'].values

# Create a squarify treemap
plt.figure(figsize=(12, 8))
squarify.plot(sizes=sizes, label=assistance_data.index, alpha=0.8)

# Add titles and labels
plt.title('Packed Bubble Chart - Types of Assistance Received by Artists')
plt.axis('off')  # Remove axis labels

plt.show()

# %%
import pandas as pd
import plotly.express as px

# Your data preparation (similar to the code you provided)
assistance_columns = [col for col in df5.columns if 'assistance_' in col]
assistance_columns = assistance_columns[:len(assistance_columns) - 1]
assistance_data = df5[assistance_columns].sum().sort_values()

# Create a dataframe from the sorted data
data = pd.DataFrame({'Assistance Type': assistance_data.index, 'Count': assistance_data.values})

# Create the interactive packed bubble chart using Plotly Express
fig = px.treemap(data, path=['Assistance Type'], values='Count')

# Update layout for better visualization (optional)
fig.update_layout(title='Interactive Packed Bubble Chart - Types of Assistance Received by Artists')

# Show the interactive plot
fig.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
import pandas as pd
import plotly.express as px

# Your data preparation (similar to the code you provided)
assistance_columns = [col for col in df5.columns if 'assistance_' in col]
assistance_columns = assistance_columns[:len(assistance_columns) - 1]
assistance_data = df5[assistance_columns].sum().sort_values()

# Create a dataframe from the sorted data
data = pd.DataFrame({'Assistance Type': assistance_data.index, 'Count': assistance_data.values})

# Create the interactive packed bubble chart with custom colors using Plotly Express
fig = px.treemap(data, path=['Assistance Type'], values='Count', color='Count',
                 color_continuous_scale='RdBu', range_color=(0, max(data['Count'])),
                 color_continuous_midpoint=max(data['Count']) / 2)

# Update layout for better visualization (optional)
fig.update_layout(title='Interactive Packed Bubble Chart - Types of Assistance Received by Artists')

# Show the interactive plot
fig.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the visualisation settings
sns.set(style="whitegrid")

# Calculate the sum of each 'approach' column to see how many artists engage in each approach
approach_columns = [col for col in df5.columns if 'approach_' in col]
approach_data = df5[approach_columns].sum().sort_values()

# Calculate the sum of each 'assistance_' column to see how many artists received each type of assistance
# assistance_columns = [col for col in df5.columns if 'assistance_' in col]
# assistance_data = df5[assistance_columns].sum().sort_values()

assistance_columns = [col for col in df5.columns if 'assistance_' in col]
assistance_columns=assistance_columns[:len(assistance_columns)-1]
# assistance_columns
assistance_data = df5[assistance_columns].sum().sort_values()

# Calculate the sum of each 'Wellbeing_Impact_' column to see the impact on artists' wellbeing
wellbeing_columns = [col for col in df5.columns if 'Wellbeing_Impact_' in col]
wellbeing_data = df5[wellbeing_columns].sum().sort_values()

# Create bar plots for approach, assistance, and wellbeing data
fig, ax = plt.subplots(3, 1, figsize=(12, 18))

# Plot for approach data
sns.barplot(x=approach_data.values, y=approach_data.index, ax=ax[0], palette="viridis")
ax[0].set_title('Prevalence of Artistic Approaches')
ax[0].set_xlabel('Number of Artists')
ax[0].set_ylabel('Approaches')

# Plot for assistance data
sns.barplot(x=assistance_data.values, y=assistance_data.index, ax=ax[1], palette="magma")
ax[1].set_title('Types of Assistance Received by Artists')
ax[1].set_xlabel('Number of Artists')
ax[1].set_ylabel('Types of Assistance')

# Plot for wellbeing data
sns.barplot(x=wellbeing_data.values, y=wellbeing_data.index, ax=ax[2], palette="cubehelix")
ax[2].set_title('Reported Well-being Impacts on Artists')
ax[2].set_xlabel('Number of Artists')
ax[2].set_ylabel('Well-being Impacts')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Assuming df5 contains the relevant data
# Define the income brackets and their corresponding values
income_brackets = ['Under $15,000', '$25,000 to $34,999', '$35,000 to $49,999', '$15,000 to $24,999', 'Prefer not to answer', '$75,000 to $99,999', '$50,000 to $74,999', '$100,000 to $149,999', 'Over $150,000']

# Initialize an empty dictionary to store counts
income_counts = {bracket: 0 for bracket in income_brackets}

# Count the occurrences of each income bracket in the DataFrame
for bracket in income_brackets:
    count = (df5['p9_2021hhincome'] == bracket).sum()
    income_counts[bracket] = count

# Print or use the income counts as needed
print(income_counts)
# Out:
# {'Under $15,000': 3768, '$25,000 to $34,999': 2346, '$35,000 to $49,999': 1393, '$15,000 to $24,999': 3858, 'Prefer not to answer': 575, '$75,000 to $99,999': 181, '$50,000 to $74,999': 622, '$100,000 to $149,999': 59, 'Over $150,000': 17}

# %%
import pandas as pd

# Assuming df5 contains the relevant data
# Define the income brackets and their corresponding values
income_brackets = ['Under $15,000', '$25,000 to $34,999', '$35,000 to $49,999', '$15,000 to $24,999', 'Prefer not to answer', '$75,000 to $99,999', '$50,000 to $74,999', '$100,000 to $149,999', 'Over $150,000']

# Define the assistance types
assistance_types = ['assistance_Emergency_Grant', 'assistance_Family_Personal_Assist', 'assistance_Federal_Relief', 'assistance_Mutual_Aid', 'assistance_Other_Assistance', 'assistance_Unemployment_Benefits']

# Initialize an empty dictionary to store counts
income_assistance_counts = {bracket: {assistance: 0 for assistance in assistance_types} for bracket in income_brackets}

# Count the occurrences of each assistance type within each income bracket
for bracket in income_brackets:
    for assistance in assistance_types:
        count = ((df5['p9_2021hhincome'] == bracket) & (df5[assistance] == 1)).sum()
        income_assistance_counts[bracket][assistance] = [count]

# Print or use the income-assistance counts as needed
print(income_assistance_counts)
# Out:
# {'Under $15,000': {'assistance_Emergency_Grant': [447], 'assistance_Family_Personal_Assist': [385], 'assistance_Federal_Relief': [780], 'assistance_Mutual_Aid': [145], 'assistance_Other_Assistance': [186], 'assistance_Unemployment_Benefits': [1818]}, '$25,000 to $34,999': {'assistance_Emergency_Grant': [374], 'assistance_Family_Personal_Assist': [275], 'assistance_Federal_Relief': [686], 'assistance_Mutual_Aid': [94], 'assistance_Other_Assistance': [101], 'assistance_Unemployment_Benefits': [1474]}, '$35,000 to $49,999': {'assistance_Emergency_Grant': [252], 'assistance_Family_Personal_Assist': [148], 'assistance_Federal_Relief': [435], 'assistance_Mutual_Aid': [42], 'assistance_Other_Assistance': [59], 'assistance_Unemployment_Benefits': [823]}, '$15,000 to $24,999': {'assistance_Emergency_Grant': [584], 'assistance_Family_Personal_Assist': [462], 'assistance_Federal_Relief': [972], 'assistance_Mutual_Aid': [170], 'assistance_Other_Assistance': [172], 'assistance_Unemployment_Benefi
# ...

# %%
income_assistance_counts

new_dict={}
for key,value in income_assistance_counts.items():
    #print(key)
    for x,y in value.items():
        if( x not in new_dict):
            new_dict[x]=[y][0]
        else:
            new_dict[x].append(y[0])
        #print(y)
new_dict
# Out:
# {'assistance_Emergency_Grant': [447, 374, 252, 584, 53, 18, 105, 10, 3],
#  'assistance_Family_Personal_Assist': [385, 275, 148, 462, 49, 9, 67, 8, 1],
#  'assistance_Federal_Relief': [780, 686, 435, 972, 100, 72, 210, 29, 4],
#  'assistance_Mutual_Aid': [145, 94, 42, 170, 9, 0, 18, 0, 0],
#  'assistance_Other_Assistance': [186, 101, 59, 172, 23, 6, 32, 3, 1],
#  'assistance_Unemployment_Benefits': [1818,
#   1474,
#   823,
#   2508,
#   273,
#   74,
#   269,
#   26,
#   6]}

# %%
new_dict
# income_bracets_
# Out:
# {'assistance_Emergency_Grant': [447, 374, 252, 584, 53, 18, 105, 10, 3],
#  'assistance_Family_Personal_Assist': [385, 275, 148, 462, 49, 9, 67, 8, 1],
#  'assistance_Federal_Relief': [780, 686, 435, 972, 100, 72, 210, 29, 4],
#  'assistance_Mutual_Aid': [145, 94, 42, 170, 9, 0, 18, 0, 0],
#  'assistance_Other_Assistance': [186, 101, 59, 172, 23, 6, 32, 3, 1],
#  'assistance_Unemployment_Benefits': [1818,
#   1474,
#   823,
#   2508,
#   273,
#   74,
#   269,
#   26,
#   6]}

# %%
df123 = pd.DataFrame.from_dict(new_dict, orient='index')
# df123.index = income_brackets
df123
# Out:
#                                       0     1    2     3    4   5    6   7  8
# assistance_Emergency_Grant          447   374  252   584   53  18  105  10  3
# assistance_Family_Personal_Assist   385   275  148   462   49   9   67   8  1
# assistance_Federal_Relief           780   686  435   972  100  72  210  29  4
# assistance_Mutual_Aid               145    94   42   170    9   0   18   0  0
# assistance_Other_Assistance         186   101   59   172   23   6   32   3  1
# assistance_Unemployment_Benefits   1818  1474  823  2508  273  74  269  26  6

# %%
# Mock-up data for demonstration purposes
# This would normally be replaced by the actual data from the CRNY dataset
income_support_data = {
   # 'Income Bracket': ['Under $25k', '$25k-$50k', '$50k-$75k', 'Over $75k'],
   'Income Bracket': ['Under $15,000', '$25,000 to $34,999','$35,000 to $49,999','$15,000 to $24,999', 'Prefer not to answer', '$75,000 to $99,999','$50,000 to $74,999','$100,000 to $149,999', 'Over $150,000']
    'Number of Artists': [300, 150, 100, 50],
    'Receiving Public Assistance': [200, 120, 60, 20]
}

# Create a DataFrame
df_income_support = pd.DataFrame(income_support_data)

# Create the bar plot for income brackets and public assistance
plt.figure(figsize=(10, 6))
sns.barplot(x='Income Bracket', y='Number of Artists', data=df_income_support, label='Total', color='lightblue')
sns.barplot(x='Income Bracket', y='Receiving Public Assistance', data=df_income_support, label='Receiving Public Assistance', color='darkblue')

# Adding the legend
plt.legend()

# Adding titles and labels
plt.title('Dynamic Income and Support Dashboard')
plt.xlabel('Income Bracket')
plt.ylabel('Number of Artists')

plt.show()
# Out:
#   Input In [221]
#     'Number of Artists': [300, 150, 100, 50],
#     ^
# SyntaxError: invalid syntax

# %%
# Mock-up data for demonstration purposes
# This would normally be replaced by the actual data from the CRNY dataset
income_support_data = {
   # 'Income Bracket': ['Under $25k', '$25k-$50k', '$50k-$75k', 'Over $75k'],
   'Income Bracket': ['Under $15,000', '$25,000 to $34,999','$35,000 to $49,999','$15,000 to $24,999', 'Prefer not to answer', '$75,000 to $99,999','$50,000 to $74,999','$100,000 to $149,999', 'Over $150,000'],
   'assistance_Emergency_Grant': [447, 374, 252, 584, 53, 18, 105, 10, 3],
   'assistance_Family_Personal_Assist': [385, 275, 148, 462, 49, 9, 67, 8, 1],
   'assistance_Federal_Relief': [780, 686, 435, 972, 100, 72, 210, 29, 4],
   'assistance_Mutual_Aid': [145, 94, 42, 170, 9, 0, 18, 0, 0],
   'assistance_Other_Assistance': [186, 101, 59, 172, 23, 6, 32, 3, 1],
   'assistance_Unemployment_Benefits': [1818,1474,823,2508,273,74,269,26,6]
}

# Create a DataFrame
df_income_support = pd.DataFrame(income_support_data)

# Create the bar plot for income brackets and public assistance
plt.figure(figsize=(10, 6))
sns.barplot(x='Income Bracket', y='Number of Artists', data=df_income_support, label='Total', color='lightblue')
sns.barplot(x='Income Bracket', y='Receiving Public Assistance', data=df_income_support, label='Receiving Public Assistance', color='darkblue')

# Adding the legend
plt.legend()

# Adding titles and labels
plt.title('Dynamic Income and Support Dashboard')
plt.xlabel('Income Bracket')
plt.ylabel('Number of Artists')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [222], in <cell line: 19>()
#      17 # Create the bar plot for income brackets and public assistance
#      18 plt.figure(figsize=(10, 6))
# ---> 19 sns.barplot(x='Income Bracket', y='Number of Artists', data=df_income_support, label='Total', color='lightblue')
#      20 sns.barplot(x='Income Bracket', y='Receiving Public Assistance', data=df_income_support, label='Receiving Public Assistance', color='darkblue')
#      22 # Adding the legend
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame from the income_support_data dictionary
df_income_support = pd.DataFrame(income_support_data)

# Define the order of income brackets for better visualization
income_bracket_order = ['Under $15,000', '$15,000 to $24,999', '$25,000 to $34,999', '$35,000 to $49,999',
                        '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 to $149,999', 'Over $150,000',
                        'Prefer not to answer']

# Create a bar plot for each type of assistance within income brackets
plt.figure(figsize=(12, 8))
sns.barplot(x='Income Bracket', y='assistance_Emergency_Grant', data=df_income_support, order=income_bracket_order, label='Emergency Grant', color='#990000')
sns.barplot(x='Income Bracket', y='assistance_Family_Personal_Assist', data=df_income_support, order=income_bracket_order, label='Family Personal Assist', color='#FF6666')
sns.barplot(x='Income Bracket', y='assistance_Federal_Relief', data=df_income_support, order=income_bracket_order, label='Federal Relief', color='#FF9999')
sns.barplot(x='Income Bracket', y='assistance_Mutual_Aid', data=df_income_support, order=income_bracket_order, label='Mutual Aid', color='#FFCCCC')
sns.barplot(x='Income Bracket', y='assistance_Other_Assistance', data=df_income_support, order=income_bracket_order, label='Other Assistance', color='#FFE5E5')
sns.barplot(x='Income Bracket', y='assistance_Unemployment_Benefits', data=df_income_support, order=income_bracket_order, label='Unemployment Benefits', color='#FF4D4D')

# Adding the legend
plt.legend(loc='upper right')

# Adding titles and labels
plt.title('Types of Assistance by Income Bracket')
plt.xlabel('Income Bracket')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Provided data
data = {
    'Income Bracket': ['Under $15,000', '$25,000 to $34,999', '$35,000 to $49,999', '$15,000 to $24,999',
                       'Prefer not to answer', '$75,000 to $99,999', '$50,000 to $74,999',
                       '$100,000 to $149,999', 'Over $150,000'],
    'assistance_Emergency_Grant': [447, 374, 252, 584, 53, 18, 105, 10, 3],
    'assistance_Family_Personal_Assist': [385, 275, 148, 462, 49, 9, 67, 8, 1],
    'assistance_Federal_Relief': [780, 686, 435, 972, 100, 72, 210, 29, 4],
    'assistance_Mutual_Aid': [145, 94, 42, 170, 9, 0, 18, 0, 0],
    'assistance_Other_Assistance': [186, 101, 59, 172, 23, 6, 32, 3, 1],
    'assistance_Unemployment_Benefits': [1818, 1474, 823, 2508, 273, 74, 269, 26, 6]
}

# Create a DataFrame from the provided data
df = pd.DataFrame(data)

# Set the 'Income Bracket' column as the index
df.set_index('Income Bracket', inplace=True)

# Transpose the DataFrame to have income brackets as columns
df = df.transpose()

# Create a stacked bar plot
plt.figure(figsize=(12, 8))
ax = df.plot(kind='bar', stacked=True, colormap='tab20')

# Adding titles and labels
plt.title('Stacked Bar Plot of Assistance Types by Income Bracket')
plt.xlabel('Income Bracket')
plt.ylabel('Count')

# Customize legend
plt.legend(title='Assistance Type', loc='upper right', bbox_to_anchor=(1.2, 1))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# Ratting 1-5 Attributes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the mapping of old column names to new names
name_mapping = {
    "p15_physicalhealth": "Physical Health",
    "p16_mentalhealth": "Mental & Emotional Health",
    "p17_stablehousing": "Housing Needs",
    "p18_feedmyself": "Food Availibility",
    "p19_socialrelationships": "Social Relationships",
    "p20_purposefullife": "Purposeful & Meaningful Life",
    "p21_agency": "Agency Over Future",
    "p22_optimistic": "Optimistic Future",
}

# Rename the columns in the DataFrame
df5_renamed = df5.rename(columns=name_mapping)

# Compute the average rating for each attribute in the renamed DataFrame
avg_ratings = df5_renamed[list(name_mapping.values())].mean()

# Sort the average ratings in ascending order
sorted_avg_ratings = avg_ratings.sort_values(ascending=False)

# Create a DataFrame for the heatmap
heatmap_data = pd.DataFrame(sorted_avg_ratings).T



# Create a horizontal heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(heatmap_data.T, annot=True, cmap="RdYlGn", cbar_kws={'label': 'Average Rating'})
plt.title("Average overall well-being of artists")
plt.ylabel("Well being attributes")
plt.xlabel("Rating Scale")
plt.xticks(rotation=0)  # No need to rotate x-axis labels
plt.yticks(rotation=0)  # Make y-axis labels horizontal for readability
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the mapping of old column names to new names
name_mapping = {
    "p5_amountofenergy": "Amount of Energy",
    "p6_amountoftime": "Amount of Time",
    "p7_financialcapacity": "Financial Capacity",
    "p8_financialstability": "Financial Stability"
}

# Rename the columns in the DataFrame
df5_renamed = df5.rename(columns=name_mapping)

# Compute the average rating for each attribute in the renamed DataFrame
avg_ratings = df5_renamed[list(name_mapping.values())].mean()

# Sort the average ratings in ascending order
sorted_avg_ratings = avg_ratings.sort_values(ascending=False)

# Create a DataFrame for the heatmap
heatmap_data = pd.DataFrame(sorted_avg_ratings).T



# Create a horizontal heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(heatmap_data.T, annot=True, cmap="RdYlGn", cbar_kws={'label': 'Average Rating'})
plt.title("Average overall well-being of artists")
plt.ylabel("Well being attributes")
plt.xlabel("Rating Scale")
plt.xticks(rotation=0)  # No need to rotate x-axis labels
plt.yticks(rotation=0)  # Make y-axis labels horizontal for readability
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming data_dict contains the mapping and df5 is the DataFrame
earning_columns = data_dict['earning_info']

# Calculate the average (or total) earnings for each category
average_earnings = df5[earning_columns].sum()

# Create a bar chart
plt.figure(figsize=(12, 6))
average_earnings.sort_values().plot(kind='bar', color='teal')
plt.title('Earnings in Different Categories')
plt.xlabel('Earnings Categories')
plt.ylabel('No. of Artists')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data_dict' is your dictionary and 'df5' is your DataFrame
earning_info_columns = data_dict['earning_info']  # Replace with actual dictionary access if different

# Calculate the sum (or count of 1s) for each column in earning_info
earning_info_sums = df5[earning_info_columns].sum()

# Sort the sums in descending order
sorted_sums = earning_info_sums.sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x=sorted_sums.values, y=sorted_sums.index, palette='viridis')

# Add titles and labels
plt.title('Counts of Positive Responses for Earning Information Attributes')
plt.xlabel('Count of Positive Responses (1s)')
plt.ylabel('Attributes')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming 'data_dict' is your dictionary and 'df5' is your DataFrame
earning_info_columns = data_dict['earning_info']  # Get column names related to 'earning_info'

# Calculate the sum of each earning-related column
earning_sums = df5[earning_info_columns].sum()

# Number of variables we're plotting
num_vars = len(earning_sums)

# Compute angle each bar is centered on:
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The plot is circular, so we need to "complete the loop"
earning_sums = pd.concat([earning_sums, earning_sums.iloc[:1]])
angles += angles[:1]

# Draw the radar chart
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, earning_sums, color='red', alpha=0.25)
ax.plot(angles, earning_sums, color='red', linewidth=2)  # Draw the outline of our data

# Labels for each point
ax.set_xticks(angles[:-1])
ax.set_xticklabels(earning_info_columns)

# Title for the chart
plt.title('Earning Information Radar Chart', size=20, color='red', y=1.1)

plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the percentage distribution of answers
other_income_counts = df5['p11_otherincome'].value_counts(normalize=True) * 100

# Create a donut chart
plt.figure(figsize=(8, 8))
plt.pie(other_income_counts, labels=other_income_counts.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3), colors=plt.cm.Paired.colors)
plt.title('Percentage Distribution of "Other Income" Responses')
plt.show()

# %%
import matplotlib.pyplot as plt
import squarify  # You might need to install this package

# Assuming 'df5' is your DataFrame
# Calculate the count distribution of answers
other_income_counts = df5['p11_otherincome'].value_counts()

# Prepare data for the treemap
labels = other_income_counts.index
sizes = other_income_counts.values
colors = [plt.cm.Spectral(i/float(len(labels))) for i in range(len(labels))]

# Create a treemap
plt.figure(figsize=(12, 8))
squarify.plot(sizes=sizes, label=labels, color=colors, alpha=0.7)
plt.title('Treemap of "Other Income" Responses')
plt.axis('off')  # Removes the axes for a clean look
plt.show()

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a histogram for the 2021 household income
plt.figure(figsize=(12, 6))
sns.histplot(df5['p9_2021hhincome'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Household Income for 2021')
plt.xlabel('2021 Household Income')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the order of income categories
income_order = [
    'Under $15,000', '$15,000 to $24,999', '$25,000 to $34,999',
    '$35,000 to $49,999', '$50,000 to $74,999', 
    '$75,000 to $99,999', '$100,000 to $149,999', 'Over $150,000',
  
]

display_names = [
    'Under $15K', '$15K - $25K', '$25K - $40K',
    '$35K - $50K', '$50K - $75K', 
    '$75K - $100K', '$100K - $140K', 'Over $150K',
   
]

# Create a bar chart for the 2021 household income with the specified order
plt.figure(figsize=(12, 6))
sns.countplot(data=df5, x='p9_2021hhincome', order=income_order, )
plt.title('Distribution of Household Income for 2021')
plt.xlabel('2021 Household Income')
plt.xticks(range(len(income_order)), display_names, rotation=0, ha='center')
plt.ylabel('Count of Artists →')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the order of income categories and display names
income_order = [
    'Under $15,000', '$15,000 to $24,999', '$25,000 to $34,999',
    '$35,000 to $49,999', '$50,000 to $74,999', 
    '$75,000 to $99,999', '$100,000 to $149,999', 'Over $150,000',
]

display_names = [
    'Under $15K', '$15K - $25K', '$25K - $40K',
    '$35K - $50K', '$50K - $75K', 
    '$75K - $100K', '$100K - $140K', 'Over $150K',
]


# Sample data representing the count of artists in each income category (replace this with your data)
counts = [3768, 3858, 2346, 1393, 622, 181, 59, 17]

# Calculate bubble sizes based on counts (consider the size range based on counts)
bubble_sizes = np.array(counts) * 20

# Create a bubble chart
plt.figure(figsize=(10, 8))

# Center bubble (larger one)
plt.scatter(0, 0, s=bubble_sizes[0], color='blue', alpha=0.5)

# Other bubbles surrounding the center based on size
angles = np.linspace(0, 2 * np.pi, len(income_order) - 1, endpoint=False)
radii = np.sqrt(bubble_sizes[1:] / np.pi)

x = radii * np.cos(angles)
y = radii * np.sin(angles)

plt.scatter(x, y, s=bubble_sizes[1:], color='orange', alpha=0.5)

# Set the title and remove axes
plt.title('Bubble Chart: Distribution of Household Income for 2021')
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the order of income categories and display names
income_order = [
    'Under $15,000', '$15,000 to $24,999', '$25,000 to $34,999',
    '$35,000 to $49,999', '$50,000 to $74,999', 
    '$75,000 to $99,999', '$100,000 to $149,999', 'Over $150,000',
]

display_names = [
    'Under $15K', '$15K - $25K', '$25K - $40K',
    '$35K - $50K', '$50K - $75K', 
    '$75K - $100K', '$100K - $140K', 'Over $150K',
]

# Sample data representing the count of artists in each income category (replace this with your data)
counts = [3768, 3858, 2346, 1393, 622, 181, 59, 17]

# Calculate bubble sizes based on counts (consider the size range based on counts)
bubble_sizes = np.array(counts) * 20

# Create a bubble chart
plt.figure(figsize=(10, 8))

# Center bubble (larger one)
plt.scatter(0, 0, s=bubble_sizes[0], color='blue', alpha=0.5)
plt.text(0, 0, f"{display_names[0]}\n{counts[0]}", ha='center', va='center')  # Display label with name and count

# Other bubbles surrounding the center based on size and non-overlapping positions
angles = np.linspace(0, 2 * np.pi, len(income_order) - 1, endpoint=False)
radii = np.sqrt(bubble_sizes[1:] / np.pi)

# Reduce the radius by a factor to bring bubbles closer
radius_factor = 0.6
radii *= radius_factor

# Adjust positions to prevent overlapping
text_positions = [(1.2 * rad) * np.cos(angle) for rad, angle in zip(radii, angles)]

for i, (x, y) in enumerate(zip(radii * np.cos(angles), radii * np.sin(angles))):
    plt.scatter(x, y, s=bubble_sizes[i + 1], color='orange', alpha=0.5)
    plt.text(x, y, f"{display_names[i + 1]}\n{counts[i + 1]}", ha='center', va='center')  # Display label with name and count

# Set the title and remove axes
plt.title('Bubble Chart: Distribution of Household Income for 2021')
plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the order of income categories and display names
income_order = [
    'Under $15,000', '$15,000 to $24,999', '$25,000 to $34,999',
    '$35,000 to $49,999', '$50,000 to $74,999', 
    '$75,000 to $99,999', '$100,000 to $149,999', 'Over $150,000',
]

display_names = [
    'Under $15K', '$15K - $25K', '$25K - $40K',
    '$35K - $50K', '$50K - $75K', 
    '$75K - $100K', '$100K - $140K', 'Over $150K',
]

# Create a DataFrame with counts for each income category
income_counts = df5['p9_2021hhincome'].value_counts().loc[income_order].reset_index()
income_counts.columns = ['Income Range', 'Count']

# Plotting the area plot
plt.figure(figsize=(12, 6))
sns.set_palette("viridis")  # Set color palette if desired

plt.fill_between(income_counts['Income Range'], income_counts['Count'], color='skyblue', alpha=0.5)
plt.plot(income_counts['Income Range'], income_counts['Count'], marker='o', color='blue', linewidth=2)

# Adding labels to points
for i, count in enumerate(income_counts['Count']):
    plt.text(i, count, str(count), ha='center', va='bottom', fontsize=8)

# Adding labels and title
plt.title('Distribution of Household Income for 2021')
plt.xlabel('2021 Household Income')
plt.ylabel('Count of Artists →')
plt.xticks(range(len(income_order)), display_names, rotation=0, ha='center',size=10)
plt.grid(False)  # Remove gridlines

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the order of income categories
income_order = [
    'Under $15,000', '$15,000 to $24,999', '$25,000 to $34,999',
    '$35,000 to $49,999', '$50,000 to $74,999', 
    '$75,000 to $99,999', '$100,000 to $149,999', 'Over $150,000',
]

display_names = [
    'Under $15K', '$15K - $25K', '$25K - $40K',
    '$35K - $50K', '$50K - $75K', 
    '$75K - $100K', '$100K - $140K', 'Over $150K',
]

wage_categories = [
    'Wage_Both_W2_and_freelance',
    'Wage_Dont_Know',
    'Wage_Employee_IRS',
    'Wage_Freelance_Contractor_1099',
    'Wage_Prefer_Not_to_Answer_Wages'
]

# Create a DataFrame with the specified columns for income and wage categories
df_income_wage = df5[['p9_2021hhincome'] + wage_categories]

# Melt the DataFrame to stack the wage categories
df_income_wage = df_income_wage.melt(id_vars='p9_2021hhincome', var_name='Wage Category', value_name='Count')

# Calculate the sum of each combination of income and wage category
df_counts = df_income_wage.groupby(['p9_2021hhincome', 'Wage Category']).sum().reset_index()

# Create a stacked bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data=df_counts, x='p9_2021hhincome', y='Count', hue='Wage Category', palette='Set2', order=income_order)
plt.title('Distribution of Household Income for 2021 by Wage Category')
plt.xlabel('2021 Household Income')
plt.xticks(range(len(income_order)), display_names, rotation=0, ha='center')
plt.ylabel('Count of Artists →')
plt.legend(title='Wage Categories', loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the order of income categories
income_order = [
    'Under $15,000', '$15,000 to $24,999', '$25,000 to $34,999',
    '$35,000 to $49,999', '$50,000 to $74,999',
    '$75,000 to $99,999', '$100,000 to $149,999', 'Over $150,000',
]

display_names = [
    'Under $15K', '$15K - $25K', '$25K - $40K',
    '$35K - $50K', '$50K - $75K',
    '$75K - $100K', '$100K - $140K', 'Over $150K',
]

wage_categories = [
    'Wage_Both_W2_and_freelance',
    'Wage_Dont_Know',
    'Wage_Employee_IRS',
    'Wage_Freelance_Contractor_1099',
    'Wage_Prefer_Not_to_Answer_Wages'
]

# Create a DataFrame with the specified columns for income and wage categories
df_income_wage = df5[['p9_2021hhincome'] + wage_categories]

# Melt the DataFrame to stack the wage categories
df_income_wage = df_income_wage.melt(id_vars='p9_2021hhincome', var_name='Wage Category', value_name='Count')

# Calculate the sum of each combination of income and wage category
df_counts = df_income_wage.groupby(['p9_2021hhincome', 'Wage Category']).sum().reset_index()

# Pivot the DataFrame for a stacked bar plot
df_pivot = df_counts.pivot(index='p9_2021hhincome', columns='Wage Category', values='Count')

# Create a stacked bar plot with adjusted dimensions
# plt.figure(figsize=(14, 8))
df_pivot = df_pivot.reindex(income_order)
df_pivot.plot(kind='bar', stacked=True, figsize=(14,8),colormap='Set2', width=0.8)
plt.title('Distribution of Household Income for 2021 by Wage Category')
plt.xlabel('2021 Household Income')
plt.xticks(range(len(income_order)), display_names, rotation=0, ha='center')
plt.ylabel('Count of Artists →')
plt.legend(title='Wage Categories', loc='upper right')
plt.show()
